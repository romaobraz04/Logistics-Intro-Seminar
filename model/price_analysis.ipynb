# %%
import pandas as pd
data = pd.read_csv("data/net_demand_and_price.csv")
#data.head()
price = data["Price (EUR/kWh)"]
print(len(price[price < 0]))
# Out:
# 547

# %%
ax = data.plot(
    x="Start",
    y="Price (EUR/kWh)",
    kind="line",
    figsize=(12, 6),
    xlabel="Price (EUR/kWh)",
    ylabel="Time Period",
    title="Price Over Time",
    grid=True,
    legend=False
)
